# %% [markdown]
# ## Признаки
# <ul>
#
#      'Затраты на информационные и коммуникационные технологии (ИКТ), млн. руб'
#      'Инвестиции в основной капитал, млн. руб.'
#      'Население моложе трудоспособного возраста, %'
#      'Население в трудоспособном возрасте, %'
#      'Среднегодовая численность занятых; тыс. чел.'
#      'Затраты на технологические инновации, млн. руб.'
#      'Доля занятых в возрасте 20-29 лет в общем числе занятых'
#      'Доля занятых с высшим образованием'
#      'Экспорт - дальнее зарубежье; млн долл. США'
#      'Экспорт - страны СНГ; млн долл. США'
#      'Импорт - страны СНГ; млн долл. США'
#      'Импорт - дальнее зарубежье; млн долл. США'
#      'Экспорт - интегральный показатель; млн долл. США'
#      'Импорт - интегральный показатель; млн долл. США'
#      'Плотность железнодорожных путей на конец года, км. путей на 10000 км2 территории'
#      'Плотность автомобильных дорог общего пользования с твердым покрытием на конец года; км. путей на 1000 км2 территории'
#      'Число активных абонентов фиксированного и мобильного широкополосного доступа к сети интернет на 100 человек населения'
#      'Число активных абонентов фиксированного широкополосного доступа к сети Интернет'
#      'Число активных абонентов подвижной радиотелефонной связи, использующих широкополосный доступ к сети Интернет'
#      'Расходы консолидированных бюджетов субъектов Российской Федерации на социально-культурные мероприятия, млн руб.'
#      'Численность трудоспособного населения и населения моложе трудоспособного возраста, %'
#      'Скорректированные по индексу потребительских цен консолидированные расходы бюджетов субъектов РФ на социально-культурные мероприятия на душу населения, тыс. руб. / чел.'
#      'Расходы консолидированных бюджетов субъектов Российской Федерации на социально-культурные мероприятия на душу населения, млн. руб / чел.'
#      'Скорректированные по индексу потребительских цен относительно 2009 г. консолидированные расходы бюджетов субъектов РФ на социально-культурные мероприятия на душу населения, тыс. руб. / чел, отн.2009'
#      'Доля занятых в возрасте 30-39 лет в общем числе занятых'
#      'Доля занятых в возрасте 20-39 лет в общем числе занятых'
#      'Доля выпускников ВУЗ-ов субъекта от выпускников по РФ, %'
#      'Среднемесячная номинальная начисленная заработная плата работников организаций, руб.'
#      'Задолженность физ. лиц по кредитам в номинальном выражении, млн. руб.'
#      'Задолженность физ. лиц по жилищным кредитам в номинальном выражении, млн. руб.'
#      'Задолженность физ. лиц по потребительским кредитам в номинальном выражении, млн. руб.'
#      'Задолженность по потребительским кредитам на одного занятого'
# </ul>
#
# ## Регулируется гос-вом
# <ul>
#
#      'Доходы консолидированных бюджетов субъектов РФ, млн. руб.'
#      'Расходы консолидированных бюджетов субъектов РФ; млн. руб.'
#      'Расходы региональных бюджетов по статье национальная экономика'
#      'Торговый баланс (соотношение экспорт - импорт)'
#      'Численности работников территориальных органов федеральных органов исполнительной власти'
#      'Численность работников органов местного самоуправления (на конец года); чел.'
#      'Численность работников органов исполнительной власти субъектов РФ и органов местного самоуправления; чел.'
#      'Расходы региональных бюджетов общие, млн.руб.'
#      'Расходы на общегосударственные вопросы, млн. руб.'
#      'Среднегодовой курс доллара США (по данным ЦБ РФ), руб./долл.'
# </ul>
#
# ## Качество жизни
# <ul>
#
#     'Эффективная среднемесячная производительность труда'
#     'Номинальная среднемесячная производительность труда в руб./(мес. чел.)'
#     'Стоимость фиксированного набора потребительских товаров и услуг, руб.'
#     'Индексы потребительских цен'
#     'Реальные доходы населения'
#     'Темп роста индексы потребительских цен'
#     'Среднедушевые денежные доходы населения; в месяц, руб.'
#     'Комфортность климата' нужно сказать, что он постоянен, поэтому можно не учитывать
#     'Ожидаемая продолжительность жизни при рождении; лет'
# </ul>
#
# ## Остальное
# <ul>
#
#      'Выпуск специалистов высшими учебными заведениями, тыс. чел.'
#      'Численность населения региона; на конец года; тыс. чел.'
#      'Численность рабочей силы в возрасте 15-72 лет, тыс. чел.'
#      'Индекс физического объема валового регионального продукта; %'
#      'Площадь территории по субъектам Российской Федерации; кв. км.'
#      'Плотность населения; чел./км2'
#      'Валовой региональный продукт; млн руб.'
# </ul>

# %%
import copy
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing
from scipy.stats import pearsonr
import warnings
warnings.filterwarnings("ignore")
sns.set(context='notebook', style='whitegrid', palette='deep', 
        font='sans-serif', font_scale=1, color_codes=False, rc=None)

# %%
df_data = pd.read_csv('data.csv', sep=';')
df_params = pd.read_csv('params.csv', sep=';')
df_regions = pd.read_csv('regions.csv', sep=';')
df_train = pd.read_csv('train.csv')
df_train.drop('Unnamed: 0', axis=1)
# Out:
#                                   Округ                Регион   Год  \
# 0         Центральный федеральный округ  Белгородская область  2007
# 1         Центральный федеральный округ  Белгородская область  2008
# 2         Центральный федеральный округ  Белгородская область  2009
# 3         Центральный федеральный округ  Белгородская область  2010
# 4         Центральный федеральный округ  Белгородская область  2011
# ...                                 ...                   ...   ...
# 1181  Дальневосточный федеральный округ          Чукотский АО  2016
# 1182  Дальневосточный федеральный округ          Чукотский АО  2017
# 1183  Дальневосточный федеральный округ          Чукотский АО  2005
# 1184  Дальневосточный федеральный округ          Чукотский АО  2006
# 1185  Дальневосточный федеральный округ          Чукотский АО  2018
#
#       Комфортность климата  \
# 0                      3.0
# 1                      3.0
# 2                      3.0
# 3                      3.0
# ...

# %%
df_train['Выпуск специалистов высшими учебными заведениями, %'] = 100 * df_train['Выпуск специалистов высшими учебными заведениями, тыс. чел.'] / df_train['Численность населения региона; на конец года; тыс. чел.']
df_train['ВВП региона на душу населения'] = df_train['Валовой региональный продукт; млн руб.'] / df_train['Численность населения региона; на конец года; тыс. чел.']
df_train['Расходы на общегосударственные вопросы, %'] = 100 * df_train['Расходы на общегосударственные вопросы, млн. руб.'] / df_train['Расходы региональных бюджетов общие, млн.руб.']
df_train['Расходы региональных бюджетов по статье национальная экономика, %'] = 100 * df_train['Расходы региональных бюджетов по статье национальная экономика'] / df_train['Расходы региональных бюджетов общие, млн.руб.']
df_train['Затраты на информационные и коммуникационные технологии (ИКТ), %'] = 100 * df_train['Затраты на информационные и коммуникационные технологии (ИКТ), млн. руб'] / df_train['Расходы региональных бюджетов общие, млн.руб.']
df_train['Затраты на технологические инновации, %'] = 100 * df_train['Затраты на технологические инновации, млн. руб.'] / df_train['Расходы региональных бюджетов общие, млн.руб.']
df_train['Расходы консолидированных бюджетов субъектов Российской Федерации на социально-культурные мероприятия, %'] = 100 * df_train['Расходы консолидированных бюджетов субъектов Российской Федерации на социально-культурные мероприятия, млн руб.'] / df_train['Расходы региональных бюджетов общие, млн.руб.']
df_train['Численность работников органов исполнительной власти субъектов РФ и органов местного самоуправления, %'] = 100 * df_train['Численность работников органов исполнительной власти субъектов РФ и органов местного самоуправления; чел.'] / df_train['Численность населения региона; на конец года; тыс. чел.']

# %%
df_train = df_train[df_train['Площадь территории по субъектам Российской Федерации; кв. км.'] != 0]
df_train = df_train[df_train['ВВП региона на душу населения'].notna()]

# %%
cols = df_train.columns
for i in cols:
    df_train = df_train[df_train[i].notna()]

# %%
ye = 2015
df = df_train[(df_train['Год'] == ye)]
target = 'Комфортность климата'
param = 'Округ'
df[df[target] == 0]
# Out:
# Empty DataFrame
# ...

# %%
target = 'Плотность населения; чел./км2'
p = 'Скорректированные по индексу потребительских цен консолидированные расходы бюджетов субъектов РФ на социально-культурные мероприятия на душу населения, тыс. руб. / чел.'
param0 = 'Расходы консолидированных бюджетов субъектов Российской Федерации на социально-культурные мероприятия на душу населения, млн. руб / чел.'
param1 = 'Скорректированные по индексу потребительских цен относительно 2009 г. консолидированные расходы бюджетов субъектов РФ на социально-культурные мероприятия на душу населения, тыс. руб. / чел, отн.2009'
param2 = 'Год'

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(12, 12))
# ax.set_ylim((0, 1500))
sns.lineplot(x=param2, y=param1, estimator=np.mean, data=df_train, ci=None)
sns.lineplot(x=param2, y=param0, estimator=np.mean, data=df_train, ci=None)
sns.lineplot(x=param2, y=p, estimator=np.mean, data=df_train, ci=None)
plt.legend(labels=[param1, param0, p], loc=2, prop={'size': 10})
plt.ylabel('')
plt.show()

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(12, 12))
ax.set_title(target)
sns.lineplot(x=param2, y=target, estimator=np.mean, data=df_train, ci=None)
plt.ylabel('')
plt.show()

# %%
target = 'Затраты на технологические инновации, млн. руб.'
p = 'Задолженность физ. лиц по жилищным кредитам в номинальном выражении, млн. руб.'
param0 = 'Задолженность физ. лиц по кредитам в номинальном выражении, млн. руб.'
param1 = 'Задолженность физ. лиц по потребительским кредитам в номинальном выражении, млн. руб.'
param3 = 'Задолженность по потребительским кредитам на одного занятого'
param2 = 'Год'

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(12, 12))
# ax.set_ylim((0, 1500))
sns.lineplot(x=param2, y=param1, estimator=np.mean, data=df_train, ci=None)
sns.lineplot(x=param2, y=param0, estimator=np.mean, data=df_train, ci=None)
sns.lineplot(x=param2, y=p, estimator=np.mean, data=df_train, ci=None)
plt.legend(labels=[param1, param0, p], loc=2, prop={'size': 10})
plt.ylabel('')
plt.show()

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(12, 12))
ax.set_title(target)
sns.lineplot(x=param2, y=target, estimator=np.mean, data=df_train, ci=None)
plt.ylabel('')
plt.show()

# %%
print(target+'\n')
print(p, pearsonr(df_train[target], df_train[p]))
print(p, pearsonr(df_train[target], df_train[param0]))
print(p, pearsonr(df_train[target], df_train[param1]))
# Out:
# Эффективная среднемесячная производительность труда
#
# Задолженность физ. лиц по жилищным кредитам в номинальном выражении, млн. руб. (0.21190356938298124, 9.059856231789211e-11)
# Задолженность физ. лиц по жилищным кредитам в номинальном выражении, млн. руб. (0.18493691393597653, 1.6871916305984462e-08)
# Задолженность физ. лиц по жилищным кредитам в номинальном выражении, млн. руб. (0.02742991381239087, 0.40673330961739446)

# %%
target = 'Задолженность физ. лиц по кредитам в номинальном выражении, млн. руб.'
p = 'Плотность транспортной сети на конец года, км. путей на 10000 км2 территории'
param0 = 'Плотность автомобильных дорог общего пользования с твердым покрытием на конец года; км. путей на 1000 км2 территории'
param1 = 'Плотность железнодорожных путей на конец года, км. путей на 10000 км2 территории'
param2 = 'Год'
df_train[p] = df_train[param0] + df_train[param1]

fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(12, 12))
# ax.set_ylim((0, 1500))
ax[0].set_title('Транспортная сеть')
sns.lineplot(ax=ax[0], x=param2, y=param1, estimator=np.mean, data=df_train, ci=None)
sns.lineplot(ax=ax[0], x=param2, y=param0, estimator=np.mean, data=df_train, ci=None)
sns.lineplot(ax=ax[0], x=param2, y=p, estimator=np.mean, data=df_train, ci=None)
plt.legend(labels=[param1, param0, p], loc=2, prop={'size': 10})
plt.ylabel('км. путей на 10000 км2 территории')

ax[1].set_title(target)
sns.lineplot(ax=ax[1], x=param2, y=target, estimator=np.mean, data=df_train, ci=None)
plt.ylabel('')
plt.show()

# %%
df = df_train[(df_train['Год'] == 2009) | (df_train['Год'] == 2013) | (df_train['Год'] == ye)]
# target = 'Ожидаемая продолжительность жизни при рождении; лет'
# param = 'Округ'
fig, ax = plt.subplots(nrows=1, ncols=1,  figsize=(25, 25))

ax.set_title('2008, 2013, 2017')
sns.barplot(x=param, y=target, data=df, hue='Год', estimator=np.median, ci=None)
plt.show()

d = df_train[(df_train['Год'] == ye)].groupby(by=param)[target].median()
plt.figure(figsize=(7, 7))
plt.title(str(ye) + 'г. ' + target)
plt.pie(x=d, labels=d.index)
plt.show()

# %%
d1 = df_train[(df_train['ВВП региона на душу населения'].notna()) & (df_train['ВВП региона на душу населения'] > 0 )]

# %%
l = df_train['Население моложе трудоспособного возраста, %'] + df_train['Население в трудоспособном возрасте, %']

# %%
# for i in range(4, len(df_train.columns)): 
for i in range(4, 5):
    for j in range(i+1, len(df_train.columns)):
#         param1 = df_train.columns[i]
        param1 = 'Скорректированные по индексу потребительских цен консолидированные расходы бюджетов субъектов РФ на социально-культурные мероприятия на душу населения, тыс. руб. / чел.'
        param2 = df_train.columns[j]
        d5 = df_train[df_train[param1].notna()]
        d5 = df_train[df_train[param2].notna()]
        print(param1+'\n'+param2)
        for o in df_train['Округ'].unique():
            print(o, pearsonr(d5[d5['Округ'] == o][param1], d5[d5['Округ'] == o][param2]))
        print('\n')
    print('\n\n')
# Out:
# Скорректированные по индексу потребительских цен консолидированные расходы бюджетов субъектов РФ на социально-культурные мероприятия на душу населения, тыс. руб. / чел.
# Площадь территории по субъектам Российской Федерации; кв. км.
# Центральный федеральный округ (-0.3919085685612522, 1.1311567890504564e-08)
# Северо-Западный федеральный округ (-0.23387179634665017, 0.009828794812548858)
# Южный федеральный округ (0.45925506503776625, 4.95296891901659e-05)
# Северо-Кавказский федеральный округ (0.7411700262538905, 1.2826891541980584e-14)
# Приволжский федеральный округ (0.4288495251330248, 2.8726616330955287e-08)
# Уральский федеральный округ (-0.09549900093273195, 0.44560675208827505)
# Сибирский федеральный округ (0.6352561608820135, 9.049033957535818e-14)
# Дальневосточный федеральный округ (0.5626745950541865, 2.7383755916326413e-11)
#
#
# ...

# %%
df_train[df_train["Эффективная среднемесячная производительность труда"] == 0]
# Out:
#       Unnamed: 0                              Округ                Регион  \
# 10            10      Центральный федеральный округ  Белгородская область
# 24            24      Центральный федеральный округ      Брянская область
# 38            38      Центральный федеральный округ  Владимирская область
# 52            52      Центральный федеральный округ   Воронежская область
# 66            66      Центральный федеральный округ    Ивановская область
# ...          ...                                ...                   ...
# 1126        1126  Дальневосточный федеральный округ      Амурская область
# 1140        1140  Дальневосточный федеральный округ   Магаданская область
# 1154        1154  Дальневосточный федеральный округ   Сахалинская область
# 1168        1168  Дальневосточный федеральный округ          Еврейская АО
# 1182        1182  Дальневосточный федеральный округ          Чукотский АО
#
#        Год  Комфортность климата  \
# 10    2017                   3.0
# ...

# %%
df_train[df_train[param1] == 0]
# Out:
# Empty DataFrame
# ...

# %%
param0 = ''
param1 = 'Затраты на технологические инновации, млн. руб.'
param2 = 'Год'

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(12, 12))
# ax.set_ylim((0, 1500))
sns.lineplot(x=param2, y=param1, hue='Регион', estimator=np.mean, data=df_train[df_train['Регион'] == 'Московская область'], ci=None)
plt.legend(loc=2, prop={'size': 10})
# plt.ylabel("")
plt.show()

# %%
param1 = 'Затраты на технологические инновации, млн. руб.'
param2 = 'Год'

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(12, 12))
# ax.set_ylim((0, 1500))
sns.lineplot(x=param2, y=param1, hue='Регион', estimator=np.mean, data=df_train[df_train['Регион'] == 'Московская область'], ci=None)
plt.legend(loc=2, prop={'size': 10})
# plt.ylabel("")
plt.show()

# %%
param = 'Комфортность климата'
k = 10
corrmat = df_train.corr()
cols = corrmat.nlargest(k, param)[param].index
cm = np.corrcoef(df_train[cols].values.T)
sns.set(font_scale=1.25)
plt.figure(figsize = (10, 10))
hm = sns.heatmap(cm, cbar=True, annot=True, square=True,
                fmt='.3f', annot_kws={'size': 10}, cmap='RdYlGn',
                center=0, vmax=1, vmin=-1,
                yticklabels=cols.values, xticklabels=cols.values)

# %%
param = 'Комфортность климата'
k = 10
h = [-1]
h.extend(list(range(k)))
corrmat = df_train.corr()
cols = corrmat.sort_values(by=param, ascending=True)[param][h].index
cm = np.corrcoef(df_train[cols].values.T)
sns.set(font_scale=1.25)
plt.figure(figsize = (23, 23))
hm = sns.heatmap(cm, cbar=True, annot=True, square=True,
                fmt='.2f', annot_kws={'size': 15}, cmap='RdYlGn',
                center=0, vmax=1, vmin=-1,
                yticklabels=cols.values, xticklabels=cols.values)

# %%
pearsonr(df_train[param1], df_train[param0])
# Out:
# (0.11870143556193896, 0.0003153437464732927)

# %%
param0 = 'Ожидаемая продолжительность жизни при рождении; лет'
# param1 = 'Затраты на технологические инновации, млн. руб.'
# 'Плотность железнодорожных путей на конец года, км. путей на 10000 км2 территории'
param1 = 'Плотность автомобильных дорог общего пользования с твердым покрытием на конец года; км. путей на 1000 км2 территории'
param2 = 'Год'

fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(24, 12))
# ax.set_ylim((0, 1500))
ax[0].set_title(param1)
sns.lineplot(ax=ax[0], x=param2, y=param1, estimator=np.mean, data=df_train, ci=None)
ax[1].set_title(param0)
sns.lineplot(ax=ax[1], x=param2, y=param0, estimator=np.mean, data=df_train, ci=None)
plt.ylabel('')
plt.show()

# %%
param1 = 'Скорректированные по индексу потребительских цен консолидированные расходы бюджетов субъектов РФ на социально-культурные мероприятия на душу населения, тыс. руб. / чел.'
param0 = 'Задолженность физ. лиц по кредитам в номинальном выражении, млн. руб.'
param2 = 'Год'
# data  = df_train[(df_train['Год'] < 2017) & (df_train['Округ'] == 'Южный федеральный округ')]
# data  = df_train[(df_train['Год'] < 2017)]
data = df_train
fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(12, 24))
# ax.set_ylim((0, 1500))
#ax[0].set_title(param1)
sns.lineplot(ax=ax[0], x=param2, hue='Округ', y=param1, estimator=np.mean, data=data, ci=None)
ax[1].set_title(param0)
sns.lineplot(ax=ax[1], x=param2, hue='Округ', y=param0, estimator=np.mean, data=data, ci=None)
plt.ylabel('')
plt.show()
